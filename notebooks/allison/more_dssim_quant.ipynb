# %%
# Add ldcpy root to system path
import sys
sys.path.insert(0,'/Users/abaker/alli/code-repo/ldcpy')
                    
# Import ldcpy package
# Autoreloads package everytime the package is called, so changes to code will be reflected in the notebook if the above sys.path.insert(...) line is uncommented.
# %load_ext autoreload
# %autoreload 2
import ldcpy

#display the plots in this notebook
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
all_prect_col = ldcpy.open_datasets("cam-fv",
    ["PRECT"],
    [
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.orig.daily.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.p6.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.p8.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.p10.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.p12.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.p14.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.p16.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.p18.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.p20.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.p22.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/PRECT/PRECT.p24.daily.t10.nc", 
    ],
    ["orig", "p6", "p8", "p10", "p12", "p14", "p16", "p18", "p20", "p22", "p24"])
                                
all_ts_col = ldcpy.open_datasets("cam-fv",
    ["TS"],
    [
        "/Users/abaker/alli/code-repo/test-data/TS/TS.orig.daily.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/TS/TS.p6.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/TS/TS.p8.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/TS/TS.p10.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/TS/TS.p12.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/TS/TS.p14.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/TS/TS.p16.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/TS/TS.p18.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/TS/TS.p20.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/TS/TS.p22.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/TS/TS.p24.daily.t10.nc", 
    ],
    ["orig", "p6", "p8", "p10", "p12", "p14", "p16", "p18", "p20", "p22", "p24"])
                                   
all_flut_col = ldcpy.open_datasets("cam-fv",
    ["FLUT"],
    [
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.orig.daily.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.p6.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.p8.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.p10.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.p12.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.p14.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.p16.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.p18.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.p20.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.p22.daily.t10.nc", 
        "/Users/abaker/alli/code-repo/test-data/FLUT/FLUT.p24.daily.t10.nc", 
    ],
    ["orig", "p6", "p8", "p10", "p12", "p14", "p16", "p18", "p20", "p22", "p24"])

all_ps_col = ldcpy.open_datasets("cam-fv",
    ["PS"],
    [
        "/Users/abaker/alli/code-repo/test-data/PS/PS.orig.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PS/PS.p6.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PS/PS.p8.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PS/PS.p10.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PS/PS.p12.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PS/PS.p14.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PS/PS.p16.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PS/PS.p18.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PS/PS.p20.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PS/PS.p22.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/PS/PS.p24.monthly.t10.nc",


    ],
    ["orig", "p6", "p8", "p10", "p12", "p14", "p16", "p18", "p20", "p22", "p24"])
                                               
all_qflx_col = ldcpy.open_datasets("cam-fv",
    ["QFLX"],
    [
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.orig.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.p6.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.p8.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.p10.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.p12.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.p14.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.p16.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.p18.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.p20.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.p22.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/QFLX/QFLX.p24.monthly.t10.nc",


    ],
    ["orig", "p6", "p8", "p10", "p12", "p14", "p16", "p18", "p20", "p22", "p24"])
          
all_cloud_col = ldcpy.open_datasets("cam-fv",
    ["CLOUD"],
    [
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.orig.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.p6.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.p8.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.p10.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.p12.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.p14.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.p16.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.p18.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.p20.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.p22.monthly.t10.nc",
        "/Users/abaker/alli/code-repo/test-data/CLOUD/CLOUD.p24.monthly.t10.nc",


    ],
    ["orig", "p6", "p8", "p10", "p12", "p14", "p16", "p18", "p20", "p22", "p24"])
# Out:
# dataset size in GB 0.03
#
# dataset size in GB 0.03
#
# dataset size in GB 0.03
#
# dataset size in GB 0.03
#
# dataset size in GB 0.03
#
# dataset size in GB 0.73

# %%
import numpy as np

vnames = ["TS", "PRECT", "PS", "FLUT", "QFLX","CLOUD"]
#vnames = ["TS", "PRECT", "CLOUD"]
ds = [all_ts_col, all_prect_col, all_ps_col, all_flut_col, all_qflx_col, all_cloud_col]
#ds = [all_ts_col, all_prect_col, all_cloud_col]

val = "p14"
q_values = [32, 64, 128, 256, 512, 1024, 2048, 0]
q_values = [16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 0]

num = len(q_values)
nvar = len(vnames)

a_dssim_exp = np.zeros((num, nvar))
ts_ssim = np.zeros(nvar)
ts_dssim = np.zeros(nvar)

for j, varname in enumerate(vnames):
    print(varname)
    #just doing t=0
    for i in range(1):
        if varname == "CLOUD":
            ts_orig = ds[j][varname].sel(collection="orig").isel(time=i).isel(lev = 20).compute()
            ts_comp = ds[j][varname].sel(collection=val).isel(time=i).isel(lev=20).compute()
        else:        
            ts_orig = ds[j][varname].sel(collection="orig").isel(time=i).compute()
            ts_comp = ds[j][varname].sel(collection=val).isel(time=i).compute()

        ts_differ = ldcpy.calcs.Diffcalcs(ts_orig, ts_comp, "cam-fv")
        
        ts_dssim[j] = ts_differ.get_diff_calc('ssim_fp')
        ts_ssim[j] = ts_differ.get_diff_calc('ssim')
    
        for q, q_val in enumerate(q_values):
            ts_differ.quant = q_val
            ts_differ.k1 = 1e-8
            ts_differ.k2 = 1e-8
            #print('----------------------')
            #print("quant = ", ts_differ.quant)
        
            ts_dssim_exp = ts_differ.get_diff_calc('ssim_fp_exp')
            #print(ts_dssim_exp)
            a_dssim_exp[q,j] = ts_dssim_exp
# Out:
# TS
# PRECT
# PS
# FLUT
# QFLX
# CLOUD

# %%
my_labels = []
for q in q_values:
  my_labels.append(str(q)) 

nvar = len(vnames)

from matplotlib import pyplot as plt
fig, axs = plt.subplots(nvar,1,figsize=(8,32))
#fig, axs = plt.subplots(nvar,1,figsize=(8,15))

for p,name in enumerate(vnames):
    axs[p].plot(my_labels, a_dssim_exp[:,p] , 'r', label = "DSSIM-EXP")
    axs[p].plot(my_labels,  np.full(num, ts_ssim[p])    , 'g:',label = "Default SSIM")
    axs[p].plot(my_labels,  np.full(num, ts_dssim[p])    , 'r:',label = "Default DSSIM")

    #tmp_a = np.zeros(num*3)
    #np.concatenate((a_dssim[:,p],a_sf_ssim[:,p], a_ssim[:,p]), out = tmp_a)
    #minlim = min(tmp_a)
    #axs[p].set_ylim([minlim, 1.0])

    axs[p].legend(fontsize=14)
    axs[p].set_title(f"{name} - zfp14")
    axs[p].set_xlabel("quantization bins (0 = none)", fontsize=14)
    axs[p].set_ylabel("value of SSIM variant", fontsize=14)

# %%
import numpy as np

vnames = ["TS", "PRECT", "PS", "FLUT", "QFLX", "CLOUD"]
#vnames = ["TS", "PRECT", "CLOUD"]
ds = [all_ts_col, all_prect_col, all_ps_col, all_flut_col, all_qflx_col, all_cloud_col]
#ds = [all_ts_col, all_prect_col, all_cloud_col]

val = "p8"
q_values = [16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 0]
num = len(q_values)
nvar = len(vnames)

a_dssim_exp = np.zeros((num, nvar))
ts_ssim = np.zeros(nvar)
ts_dssim = np.zeros(nvar)

for j, varname in enumerate(vnames):
    print(varname)
    #just doing t=0
    for i in range(1):
        if varname == "CLOUD":
            ts_orig = ds[j][varname].sel(collection="orig").isel(time=i).isel(lev = 20).compute()
            ts_comp = ds[j][varname].sel(collection=val).isel(time=i).isel(lev=20).compute()
        else:        
            ts_orig = ds[j][varname].sel(collection="orig").isel(time=i).compute()
            ts_comp = ds[j][varname].sel(collection=val).isel(time=i).compute()

        ts_differ = ldcpy.calcs.Diffcalcs(ts_orig, ts_comp, "cam-fv")
        
        ts_dssim[j] = ts_differ.get_diff_calc('ssim_fp')
        ts_ssim[j] = ts_differ.get_diff_calc('ssim')
    
        for q, q_val in enumerate(q_values):
            ts_differ.quant = q_val
            ts_differ.k1 = 1e-8
            ts_differ.k2 = 1e-8
            #print('----------------------')
            #print("quant = ", ts_differ.quant)
        
            ts_dssim_exp = ts_differ.get_diff_calc('ssim_fp_exp')
            #print(ts_dssim_exp)
            a_dssim_exp[q,j] = ts_dssim_exp
# Out:
# TS
# PRECT
# PS
# FLUT
# QFLX
# CLOUD

# %%
my_labels = []
for q in q_values:
  my_labels.append(str(q)) 

nvar = len(vnames)

from matplotlib import pyplot as plt
fig, axs = plt.subplots(nvar,1,figsize=(8,32))
#fig, axs = plt.subplots(nvar,1,figsize=(8,10))

for p,name in enumerate(vnames):
    axs[p].plot(my_labels, a_dssim_exp[:,p] , 'r', label = "DSSIM-EXP")
    axs[p].plot(my_labels,  np.full(num, ts_ssim[p])    , 'g:',label = "Default SSIM")
    axs[p].plot(my_labels,  np.full(num, ts_dssim[p])    , 'r:',label = "Default DSSIM")

    #tmp_a = np.zeros(num*3)
    #np.concatenate((a_dssim[:,p],a_sf_ssim[:,p], a_ssim[:,p]), out = tmp_a)
    #minlim = min(tmp_a)
    #axs[p].set_ylim([minlim, 1.0])

    axs[p].legend(fontsize=14)
    axs[p].set_title(f"{name} - zfp8")
    axs[p].set_xlabel("quantization bins (0 = none)", fontsize=14)
    axs[p].set_ylabel("value of SSIM variant", fontsize=14)

# %%
import numpy as np

vnames = ["TS", "PRECT", "PS", "FLUT", "QFLX", "CLOUD"]
#vnames = ["TS", "PRECT", "CLOUD"]

ds = [all_ts_col, all_prect_col, all_ps_col, all_flut_col, all_qflx_col, all_cloud_col]
#ds = [all_ts_col, all_prect_col, all_cloud_col]


val = "p20"
q_values = [32, 64, 128, 256, 512, 1024, 2048, 0]
q_values = [16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 0]

num = len(q_values)
nvar = len(vnames)

a_dssim_exp = np.zeros((num, nvar))
ts_ssim = np.zeros(nvar)
ts_dssim = np.zeros(nvar)

for j, varname in enumerate(vnames):
    print(varname)
    #just doing t=0
    for i in range(1):
        if varname == "CLOUD":
            ts_orig = ds[j][varname].sel(collection="orig").isel(time=i).isel(lev = 20).compute()
            ts_comp = ds[j][varname].sel(collection=val).isel(time=i).isel(lev=20).compute()
        else:        
            ts_orig = ds[j][varname].sel(collection="orig").isel(time=i).compute()
            ts_comp = ds[j][varname].sel(collection=val).isel(time=i).compute()

        ts_differ = ldcpy.calcs.Diffcalcs(ts_orig, ts_comp, "cam-fv")
        
        ts_dssim[j] = ts_differ.get_diff_calc('ssim_fp')
        ts_ssim[j] = ts_differ.get_diff_calc('ssim')
    
        for q, q_val in enumerate(q_values):
            ts_differ.quant = q_val
            ts_differ.k1 = 1e-8
            ts_differ.k2 = 1e-8
            #print('----------------------')
            #print("quant = ", ts_differ.quant)
        
            ts_dssim_exp = ts_differ.get_diff_calc('ssim_fp_exp')
            #print(ts_dssim_exp)
            a_dssim_exp[q,j] = ts_dssim_exp
# Out:
# TS
# PRECT
# PS
# FLUT
# QFLX
# CLOUD

# %%
my_labels = []
for q in q_values:
  my_labels.append(str(q)) 

nvar = len(vnames)

from matplotlib import pyplot as plt
fig, axs = plt.subplots(nvar,1,figsize=(8,32))
#fig, axs = plt.subplots(nvar,1,figsize=(8,10))

for p,name in enumerate(vnames):
    axs[p].plot(my_labels, a_dssim_exp[:,p] , 'r', label = "DSSIM-EXP")
    axs[p].plot(my_labels,  np.full(num, ts_ssim[p])    , 'g:',label = "Default SSIM")
    axs[p].plot(my_labels,  np.full(num, ts_dssim[p])    , 'r:',label = "Default DSSIM")

    #tmp_a = np.zeros(num*3)
    #np.concatenate((a_dssim[:,p],a_sf_ssim[:,p], a_ssim[:,p]), out = tmp_a)
    #minlim = min(tmp_a)
    #axs[p].set_ylim([minlim, 1.0])

    axs[p].legend(fontsize=14)
    axs[p].set_title(f"{name} - zfp20")
    axs[p].set_xlabel("quantization bins (0 = none)", fontsize=14)
    axs[p].set_ylabel("value of SSIM variant", fontsize=14)

# %%
cloud_col = ldcpy.open_datasets("cam-fv",
    ["CLOUD"],
    [
        "/Users/abaker/alli/code-repo/ldcpy/data/cam-fv/cam-fv.CLOUD.3months.nc",
        "/Users/abaker/alli/code-repo/ldcpy/data/cam-fv/c.fpzip.cam-fv.CLOUD.3months.nc",
    ],
    ["orig", "comp"]
)
# Out:
# dataset size in GB 0.04

# %%
cloud0 = cloud_col.isel(time=0)
ldcpy.compare_stats(cloud0, "CLOUD", ["orig", "comp"], significant_digits = 5, include_ssim=True)
# Out:
#  <span style="color:blue">Variable:  <b>CLOUD</b> </span>
#  <span style="color:green">Comparison: </span>
#                                     orig        comp
# mean                             0.11581     0.11549
# variance                        0.025229    0.025086
# standard deviation               0.15884     0.15839
# min value                              0           0
# min (abs) nonzero value       9.9202e-14  9.9032e-14
# max value                        0.94416     0.94141
# probability positive             0.67309     0.67309
# number of zeros                5.423e+05   5.423e+05
# spatial autocorr - latitude      0.98352     0.98351
# spatial autocorr - longitude     0.99168     0.99167
# entropy estimate                 0.34481     0.13741
# <br>
# <span style="color:green">Difference calcs: </span>
#                                           comp
# max abs diff                         0.0039062
# min abs diff                                 0
# ...
